# %% [markdown]
# ## web scrapping

# %%
import numpy as num

# %%
import pandas as pan

# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/mobiles/pr?sid=tyy,4io&otracker=categorytree%22"

# %%
import requests

# %%
res=requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(res.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
phones=soup.select("._4rR01T , ._3exPp9")

# %%
phones
# Out:
# [<img alt="Infinix HOT 12 Play (Daylight Green, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/l3dcl8w0/mobile/c/q/t/-original-imageg2rjgezh6yf.jpeg?q=70"/>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Daylight Green, 64 GB)</div>,
#  <img alt="POCO C31 (Royal Blue, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/ku4ezrk0/mobile/p/e/4/c31-mzb0a0jin-poco-original-imag7bzqxgdhgf2n.jpeg?q=70"/>,
#  <div class="_4rR01T">POCO C31 (Royal Blue, 64 GB)</div>,
#  <img alt="realme C20 (Cool Blue, 32 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kn7sdjk0/mobile/w/h/q/c20-rmx3063-realme-original-imagfxfzay72jqvh.jpeg?q=70"/>,
#  <div class="_4rR01T">realme C20 (Cool Blue, 32 GB)</div>,
#  <img alt="I Kall K525 (Tarnish, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/l3ahpjk0/mobile/z/u/z/k525-new-k525-new-i-kall-original-imageg5sfv7h8qgz.jpeg?q=70"/>,
# ...

# %%
phones_names=[]
phones_links=[]

# %%
for items in phones:
    phones_names.append(items.text)
    links="https://www.flipkart.com/mobiles/pr?sid=tyy,4io&otracker=categorytree%22"+"items"[4]
    phones_links.append(links)

# %%
phones_names
# Out:
# ['',
#  'Infinix HOT 12 Play (Daylight Green, 64 GB)',
#  '',
#  'POCO C31 (Royal Blue, 64 GB)',
#  '',
#  'realme C20 (Cool Blue, 32 GB)',
#  '',
#  'I Kall K525 (Tarnish, 64 GB)',
#  '',
#  'realme C20 (Cool Grey, 32 GB)',
#  '',
#  'realme Narzo 50A (Oxygen Blue, 128 GB)',
#  '',
#  'realme 9i (Prism Black, 64 GB)',
#  '',
#  'POCO M4 Pro 5G (Cool Blue, 64 GB)',
#  '',
#  'realme Narzo 50A (Oxygen Green, 128 GB)',
#  '',
#  'realme 9i (Prism Blue, 128 GB)',
#  '',
#  'realme 9i (Prism Blue, 64 GB)',
#  '',
#  'realme Narzo 50A (Oxygen Blue, 64 GB)',
#  '',
#  'realme Narzo 50A (Oxygen Green, 64 GB)',
#  '',
#  'REDMI 9i Sport (Coral Green, 64 GB)',
#  '',
#  'REDMI Note 10T 5G (Metallic Blue, 64 GB)',
#  '',
#  'realme C35 (Glowing Green, 64 GB)',
#  '',
#  'REDMI 10 (Pacific Blue, 64 GB)',
#  '',
#  'Infinix HOT 12 Play (Horizon Blue, 64 GB)',
#  '',
#  'Infinix HOT 12 Play (Racing Black, 64 GB)',
#  '',
#  'realme Narzo 30 5G (Racing Blue, 128 GB)',
#  '',
# ...

# %%
rating=soup.select("._3LWZlK")

# %%
rating
# Out:
# [<div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
# ...

# %%
for items in rating:
    rating.append("items.text")
